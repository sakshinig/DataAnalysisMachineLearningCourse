# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
stocks = pd.read_csv("AMZN.csv")

# %%
stocks
# Out:
#             Date         Open         High          Low        Close  \
# 0     1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...          ...          ...          ...          ...          ...
# 5660  2019-11-11  1778.000000  1780.000000  1767.130005  1771.650024
# 5661  2019-11-12  1774.660034  1786.219971  1771.910034  1778.000000
# 5662  2019-11-13  1773.390015  1775.000000  1747.319946  1753.109985
# 5663  2019-11-14  1751.430054  1766.589966  1749.560059  1754.599976
# 5664  2019-11-15  1760.050049  1761.680054  1732.859985  1739.489990
#
#         Adj Close    Volume
# 0        1.958333  72156000
# 1        1.729167  14700000
# 2        1.708333   6106800
# ...

# %%
stocks["High"].plot(figsize= (15, 4)) #using matplotlib's built-in data visualization
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=stocks)

# %%
stocks.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999938  0.999900  0.999840   0.999840 -0.242171
# High       0.999938  1.000000  0.999877  0.999919   0.999919 -0.240706
# Low        0.999900  0.999877  1.000000  0.999928   0.999928 -0.243796
# Close      0.999840  0.999919  0.999928  1.000000   1.000000 -0.242181
# Adj Close  0.999840  0.999919  0.999928  1.000000   1.000000 -0.242181
# Volume    -0.242171 -0.240706 -0.243796 -0.242181  -0.242181  1.000000

# %%
sns.heatmap(stocks.corr())
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(stocks["Low"])
# Out:
# <AxesSubplot:xlabel='Low'>

# %%
sns.violinplot(stocks["High"])
# Out:
# C:\Users\saksh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='High'>
