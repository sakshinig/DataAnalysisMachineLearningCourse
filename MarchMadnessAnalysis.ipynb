# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
game = pd.read_csv("2023GameData.csv")

# %%
game.describe()
# Out:
#          YEAR        SEED  TEAM ROUND  CURRENT ROUND  \
# count   148.0  148.000000       148.0          148.0
# mean   2023.0    6.567568         0.0            0.0
# std       0.0    4.472383         0.0            0.0
# min    2023.0    1.000000         0.0            0.0
# 25%    2023.0    3.000000         0.0            0.0
# 50%    2023.0    6.000000         0.0            0.0
# 75%    2023.0   10.000000         0.0            0.0
# max    2023.0   16.000000         0.0            0.0
#
#        KENPOM ADJUSTED EFFICIENCY  KENPOM ADJUSTED OFFENSE  \
# count                  148.000000               148.000000
# mean                    17.734326               114.471055
# std                      7.500217                 4.725107
# min                    -12.264600                96.610200
# 25%                     14.815600               112.209000
# 50%                     18.333700               114.701000
# 75%                     23.134500               118.327000
# ...

# %%
game
# Out:
#      YEAR  SEED                    TEAM  TEAM ROUND  CURRENT ROUND  \
# 0    2023     1                 Alabama           0              0
# 1    2023    16  Texas A&M Corpus Chris           0              0
# 2    2023     1                 Alabama           0              0
# 3    2023    16  Southeast Missouri St.           0              0
# 4    2023     1                  Purdue           0              0
# ..    ...   ...                     ...         ...            ...
# 143  2023     5                    Duke           0              0
# 144  2023     1                 Houston           0              0
# 145  2023     5                Miami FL           0              0
# 146  2023     1                  Kansas           0              0
# 147  2023     5            Saint Mary's           0              0
#
#      KENPOM ADJUSTED EFFICIENCY  KENPOM ADJUSTED OFFENSE  \
# 0                      26.93630                  115.832
# ...

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   YEAR                            148 non-null    int64
#  1   SEED                            148 non-null    int64
#  2   TEAM                            148 non-null    object
#  3   TEAM ROUND                      148 non-null    int64
#  4   CURRENT ROUND                   148 non-null    int64
#  5   KENPOM ADJUSTED EFFICIENCY      148 non-null    float64
#  6   KENPOM ADJUSTED OFFENSE         148 non-null    float64
#  7   KENPOM ADJUSTED DEFENSE         148 non-null    float64
#  8   KENPOM ADJUSTED TEMPO           148 non-null    float64
#  9   BARTTORVIK ADJUSTED EFFICIENCY  148 non-null    float64
#  10  BARTTORVIK ADJUSTED OFFENSE     148 non-null    float64
#  11  BARTTORVIK ADJUSTED DEFENSE     148 non-null    float64
# ...

# %%
sns.distplot(game["WIN %"])
# Out:
# <AxesSubplot:xlabel='WIN %', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(18,5)})
sns.barplot(x = "TEAM", y = "WIN %", data= game)
# Out:
# <AxesSubplot:xlabel='TEAM', ylabel='WIN %'>

# %%
game["TEAM"].nunique()
# Out:
# 68

# %%
game.corr()
# Out:
#                                 YEAR      SEED  TEAM ROUND  CURRENT ROUND  \
# YEAR                             NaN       NaN         NaN            NaN
# SEED                             NaN  1.000000         NaN            NaN
# TEAM ROUND                       NaN       NaN         NaN            NaN
# CURRENT ROUND                    NaN       NaN         NaN            NaN
# KENPOM ADJUSTED EFFICIENCY       NaN -0.885382         NaN            NaN
# KENPOM ADJUSTED OFFENSE          NaN -0.666878         NaN            NaN
# KENPOM ADJUSTED DEFENSE          NaN  0.645043         NaN            NaN
# KENPOM ADJUSTED TEMPO            NaN -0.015292         NaN            NaN
# BARTTORVIK ADJUSTED EFFICIENCY   NaN -0.884574         NaN            NaN
# BARTTORVIK ADJUSTED OFFENSE      NaN -0.666120         NaN            NaN
# BARTTORVIK ADJUSTED DEFENSE      NaN  0.647267         NaN            NaN
# BARTHAG                          NaN -0.804918         NaN            NaN
# ...

# %%
sns.heatmap(game.corr())
# Out:
# <AxesSubplot:>
